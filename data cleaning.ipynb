# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.formula.api as smf
import statsmodels.api as sm
from scipy.stats import t

import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import datetime as dt
import matplotlib
import matplotlib.pyplot as plt

# suppress warning
import warnings
warnings.filterwarnings('ignore')

import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
import scipy
from sklearn.metrics import r2_score
from statsmodels.graphics.tsaplots import plot_acf

import pandas_datareader.data as pdr
import yfinance as yf

# %%
data=pd.read_csv("all_data.csv")
data
# Out:
#          callsign typecode origin destination                  firstseen  \
# 0          CES219     A332   YSSY        EDDF  2018-12-31 01:05:29+00:00
# 1          AEA040     A332   LEMD        LEMD  2018-12-31 01:07:21+00:00
# 2          CXA825     B788   YSSY        LFPG  2018-12-31 01:18:29+00:00
# 3          CLU211     B744   UUEE        EDDF  2018-12-31 01:49:28+00:00
# 4          ETH704     B788   KLDJ        LFPG  2018-12-31 03:31:48+00:00
# ...           ...      ...    ...         ...                        ...
# 42424537   N749SF     B407   K1H0        MO35  2022-12-31 23:38:12+00:00
# 42424538   SDA289     C208   NZWN        NZWB  2022-12-31 23:42:19+00:00
# 42424539   N988NW     FA7X   KPBI        KFLL  2022-12-31 23:42:27+00:00
# 42424540   N835CS     EC35   MS90        K08M  2022-12-31 23:44:12+00:00
# 42424541     39BP      R22   WN80        8OR6  2022-12-31 23:48:19+00:00
#
#                            lastseen                        day
# 0         2019-01-01 04:09:29+00:00  2019-01-01 00:00:00+00:00
# 1         2019-01-01 03:32:59+00:00  2019-01-01 00:00:00+00:00
# 2         2019-01-01 04:32:28+00:00  2019-01-01 00:00:00+00:00
# 3         2019-01-01 04:11:38+00:00  2019-01-01 00:00:00+00:00
# 4         2019-01-01 04:30:10+00:00  2019-01-01 00:00:00+00:00
# ...                             ...                        ...
# 42424537  2022-12-31 23:57:10+00:00  2022-12-31 00:00:00+00:00
# 42424538  2022-12-31 23:57:29+00:00  2022-12-31 00:00:00+00:00
# 42424539  2022-12-31 23:57:27+00:00  2022-12-31 00:00:00+00:00
# 42424540  2022-12-31 23:58:55+00:00  2022-12-31 00:00:00+00:00
# 42424541  2022-12-31 23:59:29+00:00  2022-12-31 00:00:00+00:00
#
# [42424542 rows x 7 columns]

# %%
icao=pd.read_csv("iata-icao.csv")
icao
# Out:
#      country_code         region_name iata  icao  \
# 0              AE            Abu Zaby  AAN  OMAL
# 1              AE            Abu Zaby  AUH  OMAA
# 2              AE            Abu Zaby  AYM   NaN
# 3              AE            Abu Zaby  AZI  OMAD
# 4              AE            Abu Zaby  DHF  OMAM
# ...           ...                 ...  ...   ...
# 8932           ZW            Masvingo  MVZ  FVMV
# 8933           ZW  Matabeleland North  HWN  FVWN
# 8934           ZW  Matabeleland North  VFA  FVFA
# 8935           ZW  Matabeleland North  WKI  FVWT
# 8936           ZW            Midlands  GWE  FVTL
#
#                               airport  latitude  longitude
# 0        Al Ain International Airport   24.2617    55.6092
# 1     Abu Dhabi International Airport   24.4330    54.6511
# 2            Yas Island Seaplane Base   24.4670    54.6103
# 3         Al Bateen Executive Airport   24.4283    54.4581
# 4                  Al Dhafra Air Base   24.2482    54.5477
# ...                               ...       ...        ...
# 8932                 Masvingo Airport  -20.0553    30.8591
# 8933     Hwange National Park Airport  -18.6299    27.0210
# 8934           Victoria Falls Airport  -18.0959    25.8390
# 8935              Hwange Town Airport  -18.3630    26.5198
# 8936               Thornhill Air Base  -19.4364    29.8619
#
# [8937 rows x 7 columns]

# %%
uniqO = data['origin'].unique()
uniqO_df = pd.DataFrame(uniqO)
uniqO_df
# Out:
#           0
# 0      YSSY
# 1      LEMD
# 2      UUEE
# 3      KLDJ
# 4      WIII
# ...     ...
# 15273  RJSF
# 15274  LERI
# 15275  SC19
# 15276  45WY
# 15277  7GA3
#
# [15278 rows x 1 columns]

# %%
duniqO = icao['icao'].unique()
duniqO_df = pd.DataFrame(duniqO)
duniqO_df
# Out:
#          0
# 0     OMAL
# 1     OMAA
# 2      NaN
# 3     OMAD
# 4     OMAM
# ...    ...
# 7787  FVMV
# 7788  FVWN
# 7789  FVFA
# 7790  FVWT
# 7791  FVTL
#
# [7792 rows x 1 columns]

# %%
# Filter the DataFrame
filter_major_planetype = data[data['typecode'].str.startswith(('A3', 'B7', 'E1','DH','CRJ','BCS'))]

# Print the filtered DataFrame
filter_major_planetype
# Out:
#          callsign typecode origin destination                  firstseen  \
# 0          CES219     A332   YSSY        EDDF  2018-12-31 01:05:29+00:00
# 1          AEA040     A332   LEMD        LEMD  2018-12-31 01:07:21+00:00
# 2          CXA825     B788   YSSY        LFPG  2018-12-31 01:18:29+00:00
# 3          CLU211     B744   UUEE        EDDF  2018-12-31 01:49:28+00:00
# 4          ETH704     B788   KLDJ        LFPG  2018-12-31 03:31:48+00:00
# ...           ...      ...    ...         ...                        ...
# 42424528  ENY3800     E145   KORD        KCMI  2022-12-31 23:30:50+00:00
# 42424530    CFHAJ     DH3T   CYVR        CYVR  2022-12-31 23:32:33+00:00
# 42424531   VTE565     E145   KMQY        KBNA  2022-12-31 23:34:30+00:00
# 42424534    CFPCG     DHC2   2WA3        CYVR  2022-12-31 23:36:52+00:00
# 42424535  ENY3714     E145   KORD        9IL7  2022-12-31 23:37:34+00:00
#
#                            lastseen                        day
# 0         2019-01-01 04:09:29+00:00  2019-01-01 00:00:00+00:00
# 1         2019-01-01 03:32:59+00:00  2019-01-01 00:00:00+00:00
# 2         2019-01-01 04:32:28+00:00  2019-01-01 00:00:00+00:00
# 3         2019-01-01 04:11:38+00:00  2019-01-01 00:00:00+00:00
# 4         2019-01-01 04:30:10+00:00  2019-01-01 00:00:00+00:00
# ...                             ...                        ...
# 42424528  2022-12-31 23:56:58+00:00  2022-12-31 00:00:00+00:00
# 42424530  2022-12-31 23:52:52+00:00  2022-12-31 00:00:00+00:00
# 42424531  2022-12-31 23:47:15+00:00  2022-12-31 00:00:00+00:00
# 42424534  2022-12-31 23:50:34+00:00  2022-12-31 00:00:00+00:00
# 42424535  2022-12-31 23:59:42+00:00  2022-12-31 00:00:00+00:00
#
# [29022040 rows x 7 columns]

# %%
# Filter the DataFrame to include only rows where the callsign starts with three letters
filtered_df = filter_major_planetype[filter_major_planetype['callsign'].str.match(r'^[A-Z]{3}')]
# This regex: ^[A-Z]{3} ensures the string starts (^) with exactly three capital letters ([A-Z]{3})
filtered_com_major = filtered_df[~filtered_df['callsign'].str.match(r'^[A-Z]+$')]
# This regex: ^[A-Z]+$ matches strings that start and end with one or more capital letters


filtered_com_major
# Out:
#          callsign typecode origin destination                  firstseen  \
# 0          CES219     A332   YSSY        EDDF  2018-12-31 01:05:29+00:00
# 1          AEA040     A332   LEMD        LEMD  2018-12-31 01:07:21+00:00
# 2          CXA825     B788   YSSY        LFPG  2018-12-31 01:18:29+00:00
# 3          CLU211     B744   UUEE        EDDF  2018-12-31 01:49:28+00:00
# 4          ETH704     B788   KLDJ        LFPG  2018-12-31 03:31:48+00:00
# ...           ...      ...    ...         ...                        ...
# 42424525  PDT6131     E145   KMDT        KPHL  2022-12-31 23:29:15+00:00
# 42424527   JZA319     DH8D   CYQQ        CYVR  2022-12-31 23:30:43+00:00
# 42424528  ENY3800     E145   KORD        KCMI  2022-12-31 23:30:50+00:00
# 42424531   VTE565     E145   KMQY        KBNA  2022-12-31 23:34:30+00:00
# 42424535  ENY3714     E145   KORD        9IL7  2022-12-31 23:37:34+00:00
#
#                            lastseen                        day
# 0         2019-01-01 04:09:29+00:00  2019-01-01 00:00:00+00:00
# 1         2019-01-01 03:32:59+00:00  2019-01-01 00:00:00+00:00
# 2         2019-01-01 04:32:28+00:00  2019-01-01 00:00:00+00:00
# 3         2019-01-01 04:11:38+00:00  2019-01-01 00:00:00+00:00
# 4         2019-01-01 04:30:10+00:00  2019-01-01 00:00:00+00:00
# ...                             ...                        ...
# 42424525  2022-12-31 23:50:46+00:00  2022-12-31 00:00:00+00:00
# 42424527  2022-12-31 23:51:42+00:00  2022-12-31 00:00:00+00:00
# 42424528  2022-12-31 23:56:58+00:00  2022-12-31 00:00:00+00:00
# 42424531  2022-12-31 23:47:15+00:00  2022-12-31 00:00:00+00:00
# 42424535  2022-12-31 23:59:42+00:00  2022-12-31 00:00:00+00:00
#
# [28762907 rows x 7 columns]

# %%
unique_typecodes = filtered_com_major['typecode'].unique()

# Create a dictionary with all values under one key
PlaneTypes = {'Typecode': list(unique_typecodes)}

# Convert the dictionary to a DataFrame
PlaneTypes_df = pd.DataFrame(PlaneTypes)

# Display the DataFrame
PlaneTypes_df = PlaneTypes_df.sort_values(by='Typecode')
PlaneTypes_df
# Out:
#    Typecode
# 35     A306
# 61     A30B
# 15     A310
# 43     A318
# 20     A319
# ..      ...
# 29     E145
# 30     E170
# 74     E175
# 27     E190
# 48     E195
#
# [102 rows x 1 columns]

# %%
uniqO = filtered_com_major['origin'].unique()
uniqO_df = pd.DataFrame(uniqO)
uniqO_df
# Out:
#          0
# 0     YSSY
# 1     LEMD
# 2     UUEE
# 3     KLDJ
# 4     WIII
# ...    ...
# 5754  EG03
# 5755  KSTK
# 5756  LGLR
# 5757  KSFQ
# 5758  VA04
#
# [5759 rows x 1 columns]

# %%
uniqD = filtered_com_major['destination'].unique()
uniqD_df = pd.DataFrame(uniqD)
uniqD_df
# Out:
#           0
# 0      EDDF
# 1      LEMD
# 2      LFPG
# 3      RPLL
# 4      KLAX
# ...     ...
# 10757  4WI9
# 10758  LSZC
# 10759  KAKO
# 10760  ORUQ
# 10761  23XS
#
# [10762 rows x 1 columns]

# %%
filtered_com_major['day'] = pd.to_datetime(filtered_com_major['day'])
filtered_com_major
# Out:
#          callsign typecode origin destination                  firstseen  \
# 0          CES219     A332   YSSY        EDDF  2018-12-31 01:05:29+00:00
# 1          AEA040     A332   LEMD        LEMD  2018-12-31 01:07:21+00:00
# 2          CXA825     B788   YSSY        LFPG  2018-12-31 01:18:29+00:00
# 3          CLU211     B744   UUEE        EDDF  2018-12-31 01:49:28+00:00
# 4          ETH704     B788   KLDJ        LFPG  2018-12-31 03:31:48+00:00
# ...           ...      ...    ...         ...                        ...
# 42424525  PDT6131     E145   KMDT        KPHL  2022-12-31 23:29:15+00:00
# 42424527   JZA319     DH8D   CYQQ        CYVR  2022-12-31 23:30:43+00:00
# 42424528  ENY3800     E145   KORD        KCMI  2022-12-31 23:30:50+00:00
# 42424531   VTE565     E145   KMQY        KBNA  2022-12-31 23:34:30+00:00
# 42424535  ENY3714     E145   KORD        9IL7  2022-12-31 23:37:34+00:00
#
#                            lastseen                       day
# 0         2019-01-01 04:09:29+00:00 2019-01-01 00:00:00+00:00
# 1         2019-01-01 03:32:59+00:00 2019-01-01 00:00:00+00:00
# 2         2019-01-01 04:32:28+00:00 2019-01-01 00:00:00+00:00
# 3         2019-01-01 04:11:38+00:00 2019-01-01 00:00:00+00:00
# 4         2019-01-01 04:30:10+00:00 2019-01-01 00:00:00+00:00
# ...                             ...                       ...
# 42424525  2022-12-31 23:50:46+00:00 2022-12-31 00:00:00+00:00
# 42424527  2022-12-31 23:51:42+00:00 2022-12-31 00:00:00+00:00
# 42424528  2022-12-31 23:56:58+00:00 2022-12-31 00:00:00+00:00
# 42424531  2022-12-31 23:47:15+00:00 2022-12-31 00:00:00+00:00
# 42424535  2022-12-31 23:59:42+00:00 2022-12-31 00:00:00+00:00
#
# [28762907 rows x 7 columns]

# %%
filtered_com_major.dtypes
# Out:
# callsign                    object
# typecode                    object
# origin                      object
# destination                 object
# firstseen                   object
# lastseen                    object
# day            datetime64[ns, UTC]
# dtype: object

# %%
count_before = filtered_com_major.groupby('day').count()
count_before
# Out:
#                            callsign  typecode  origin  destination  firstseen  \
# day
# 2019-01-01 00:00:00+00:00     18225     18225   18225        18225      18225
# 2019-01-02 00:00:00+00:00     21528     21528   21528        21528      21528
# 2019-01-03 00:00:00+00:00     22145     22145   22145        22145      22145
# 2019-01-04 00:00:00+00:00     22501     22501   22501        22501      22501
# 2019-01-05 00:00:00+00:00     19524     19524   19524        19524      19524
# ...                             ...       ...     ...          ...        ...
# 2022-12-27 00:00:00+00:00     15784     15784   15784        15784      15784
# 2022-12-28 00:00:00+00:00     20254     20254   20254        20254      20254
# 2022-12-29 00:00:00+00:00     21117     21117   21117        21117      21117
# 2022-12-30 00:00:00+00:00     21965     21965   21965        21965      21965
# 2022-12-31 00:00:00+00:00     19617     19617   19617        19617      19617
#
#                            lastseen
# day
# 2019-01-01 00:00:00+00:00     18225
# 2019-01-02 00:00:00+00:00     21528
# 2019-01-03 00:00:00+00:00     22145
# 2019-01-04 00:00:00+00:00     22501
# 2019-01-05 00:00:00+00:00     19524
# ...                             ...
# 2022-12-27 00:00:00+00:00     15784
# 2022-12-28 00:00:00+00:00     20254
# 2022-12-29 00:00:00+00:00     21117
# 2022-12-30 00:00:00+00:00     21965
# 2022-12-31 00:00:00+00:00     19617
#
# [1458 rows x 6 columns]

# %%
plt.figure(figsize=(20, 10))
plt.plot(count_before['callsign'])
plt.show()

# %%
icaoO = pd.DataFrame()
icaoO['origin'] = icao['icao']
icaoO['Olatitude'] = icao['latitude']
icaoO['Olongitude'] = icao['longitude'] 

filtered_com_major_final = pd.merge(filtered_com_major, icaoO, on='origin', how='inner')

# %%
filtered_com_major_final
# Out:
#          callsign typecode origin destination                  firstseen  \
# 0          CES219     A332   YSSY        EDDF  2018-12-31 01:05:29+00:00
# 1          CXA825     B788   YSSY        LFPG  2018-12-31 01:18:29+00:00
# 2           HVN55     B789   YSSY        EGLL  2018-12-31 04:37:28+00:00
# 3           BAW16     B77W   YSSY        EGLL  2018-12-31 05:50:41+00:00
# 4            QFA1     A388   YSSY        EGLL  2018-12-31 06:28:52+00:00
# ...           ...      ...    ...         ...                        ...
# 27211235  SKW5843     CRJ2   KCPR        KDEN  2022-12-31 15:03:40+00:00
# 27211236  SKW4658     CRJ2   KCPR        KDEN  2022-12-31 20:47:17+00:00
# 27211237  SKW5809     CRJ2   KCPR        KDEN  2022-12-31 22:31:01+00:00
# 27211238    CVU90     DHC6   KSTK        KDEN  2022-12-27 17:48:08+00:00
# 27211239   SAM907     B737   LGLR        EINN  2022-12-28 10:36:15+00:00
#
#                            lastseen                       day  Olatitude  \
# 0         2019-01-01 04:09:29+00:00 2019-01-01 00:00:00+00:00   -33.9461
# 1         2019-01-01 04:32:28+00:00 2019-01-01 00:00:00+00:00   -33.9461
# 2         2019-01-01 06:44:42+00:00 2019-01-01 00:00:00+00:00   -33.9461
# 3         2019-01-01 05:18:06+00:00 2019-01-01 00:00:00+00:00   -33.9461
# 4         2019-01-01 06:03:57+00:00 2019-01-01 00:00:00+00:00   -33.9461
# ...                             ...                       ...        ...
# 27211235  2022-12-31 15:40:05+00:00 2022-12-31 00:00:00+00:00    42.9080
# 27211236  2022-12-31 21:24:52+00:00 2022-12-31 00:00:00+00:00    42.9080
# 27211237  2022-12-31 23:08:36+00:00 2022-12-31 00:00:00+00:00    42.9080
# 27211238  2022-12-27 18:22:06+00:00 2022-12-27 00:00:00+00:00    40.6153
# 27211239  2022-12-28 14:46:50+00:00 2022-12-28 00:00:00+00:00    39.6503
#
#           Olongitude
# 0           151.1770
# 1           151.1770
# 2           151.1770
# 3           151.1770
# 4           151.1770
# ...              ...
# 27211235   -106.4640
# 27211236   -106.4640
# 27211237   -106.4640
# 27211238   -103.2650
# 27211239     22.4655
#
# [27211240 rows x 9 columns]

# %%
icaoD = pd.DataFrame()
icaoD['destination'] = icao['icao']
icaoD['Dlatitude'] = icao['latitude']
icaoD['Dlongitude'] = icao['longitude'] 

filtered_com_major_final = pd.merge(filtered_com_major_final, icaoD, on='destination', how='inner')

# %%
filtered_com_major_final
# Out:
#          callsign typecode origin destination                  firstseen  \
# 0          CES219     A332   YSSY        EDDF  2018-12-31 01:05:29+00:00
# 1           SIA26     A388   YSSY        EDDF  2019-01-02 05:19:34+00:00
# 2           SIA26     A388   YSSY        EDDF  2019-01-03 05:29:15+00:00
# 3           SIA26     A388   YSSY        EDDF  2019-01-04 05:23:35+00:00
# 4           HVN37     B789   YSSY        EDDF  2019-01-05 04:38:41+00:00
# ...           ...      ...    ...         ...                        ...
# 24187788  GOJUMP4     DHC6   KOKB        KOKB  2022-07-31 21:34:23+00:00
# 24187789  GOJUMP4     DHC6   KOKB        KOKB  2022-08-01 20:32:15+00:00
# 24187790  SKW405L     CRJ2   KMEI        KLUL  2022-10-03 21:33:17+00:00
# 24187791  SKW405L     CRJ2   KMEI        KLUL  2022-10-19 21:26:08+00:00
# 24187792  GOW3147     A320   VEBD        VEGT  2022-10-16 03:12:16+00:00
#
#                            lastseen                       day  Olatitude  \
# 0         2019-01-01 04:09:29+00:00 2019-01-01 00:00:00+00:00   -33.9461
# 1         2019-01-03 05:34:24+00:00 2019-01-03 00:00:00+00:00   -33.9461
# 2         2019-01-04 05:13:38+00:00 2019-01-04 00:00:00+00:00   -33.9461
# 3         2019-01-05 05:58:27+00:00 2019-01-05 00:00:00+00:00   -33.9461
# 4         2019-01-06 05:15:59+00:00 2019-01-06 00:00:00+00:00   -33.9461
# ...                             ...                       ...        ...
# 24187788  2022-07-31 21:56:17+00:00 2022-07-31 00:00:00+00:00    33.2173
# 24187789  2022-08-01 20:47:10+00:00 2022-08-01 00:00:00+00:00    33.2173
# 24187790  2022-10-03 21:43:19+00:00 2022-10-03 00:00:00+00:00    32.3326
# 24187791  2022-10-19 21:37:29+00:00 2022-10-19 00:00:00+00:00    32.3326
# 24187792  2022-10-16 03:40:12+00:00 2022-10-16 00:00:00+00:00    26.6812
#
#           Olongitude  Dlatitude  Dlongitude
# 0           151.1770    50.0333     8.57056
# 1           151.1770    50.0333     8.57056
# 2           151.1770    50.0333     8.57056
# 3           151.1770    50.0333     8.57056
# 4           151.1770    50.0333     8.57056
# ...              ...        ...         ...
# 24187788   -117.3540    33.2173  -117.35400
# 24187789   -117.3540    33.2173  -117.35400
# 24187790    -88.7519    31.6726   -89.17220
# 24187791    -88.7519    31.6726   -89.17220
# 24187792     88.3286    26.1061    91.58590
#
# [24187793 rows x 11 columns]

# %%
count_after = filtered_com_major_final.groupby('day').count()
count_after
# Out:
#                            callsign  typecode  origin  destination  firstseen  \
# day
# 2019-01-01 00:00:00+00:00     14560     14560   14560        14560      14560
# 2019-01-02 00:00:00+00:00     17056     17056   17056        17056      17056
# 2019-01-03 00:00:00+00:00     17727     17727   17727        17727      17727
# 2019-01-04 00:00:00+00:00     18100     18100   18100        18100      18100
# 2019-01-05 00:00:00+00:00     15798     15798   15798        15798      15798
# ...                             ...       ...     ...          ...        ...
# 2022-12-27 00:00:00+00:00     13817     13817   13817        13817      13817
# 2022-12-28 00:00:00+00:00     17848     17848   17848        17848      17848
# 2022-12-29 00:00:00+00:00     18533     18533   18533        18533      18533
# 2022-12-30 00:00:00+00:00     19218     19218   19218        19218      19218
# 2022-12-31 00:00:00+00:00     17088     17088   17088        17088      17088
#
#                            lastseen  Olatitude  Olongitude  Dlatitude  \
# day
# 2019-01-01 00:00:00+00:00     14560      14560       14560      14560
# 2019-01-02 00:00:00+00:00     17056      17056       17056      17056
# 2019-01-03 00:00:00+00:00     17727      17727       17727      17727
# 2019-01-04 00:00:00+00:00     18100      18100       18100      18100
# 2019-01-05 00:00:00+00:00     15798      15798       15798      15798
# ...                             ...        ...         ...        ...
# 2022-12-27 00:00:00+00:00     13817      13817       13817      13817
# 2022-12-28 00:00:00+00:00     17848      17848       17848      17848
# 2022-12-29 00:00:00+00:00     18533      18533       18533      18533
# 2022-12-30 00:00:00+00:00     19218      19218       19218      19218
# 2022-12-31 00:00:00+00:00     17088      17088       17088      17088
#
#                            Dlongitude
# day
# 2019-01-01 00:00:00+00:00       14560
# 2019-01-02 00:00:00+00:00       17056
# 2019-01-03 00:00:00+00:00       17727
# 2019-01-04 00:00:00+00:00       18100
# 2019-01-05 00:00:00+00:00       15798
# ...                               ...
# 2022-12-27 00:00:00+00:00       13817
# 2022-12-28 00:00:00+00:00       17848
# 2022-12-29 00:00:00+00:00       18533
# 2022-12-30 00:00:00+00:00       19218
# 2022-12-31 00:00:00+00:00       17088
#
# [1458 rows x 10 columns]

# %%
plt.figure(figsize=(20, 10))
plt.plot(count_before['callsign'])
plt.plot(count_after['callsign'])
plt.show()

# %%
icao_set = set(icao['icao'])
destination_set = set(filtered_com_major['destination'])

# Calculate elements in row 0 not in row 1
dest_not_in_icao = destination_set.difference(icao_set)
dest_not_in_icao
# Out:
# {'MU11',
#  'KPTD',
#  'LILN',
#  'EKBH',
#  'SDTN',
#  'EBFN',
#  '53FD',
#  'FL12',
#  'K06M',
#  'WV76',
#  'K1H0',
#  '39IA',
#  '30TA',
#  '0IN4',
#  'CPL6',
#  '96WA',
#  '32NK',
#  'KASW',
#  '69IL',
#  'EHTL',
#  '59II',
#  'UNNE',
#  'LL56',
#  'CFK6',
#  'K3G6',
#  'OH21',
#  'KU10',
#  'K01M',
#  '17FA',
#  'LQPD',
#  'OJ38',
#  '78NY',
#  'NZWP',
#  '93IA',
#  '5MN4',
#  '2LL3',
#  'MS15',
#  'KC77',
#  'NC61',
#  '2TA4',
#  '71NC',
#  'KJES',
#  'K2A5',
#  'SSOI',
#  '76WA',
#  'EDRW',
#  'VA94',
#  'KM33',
#  '5MD7',
#  'EIBR',
#  '33OR',
#  'LFIB',
#  'LA87',
#  'LFFG',
#  '40PN',
#  'CSD4',
#  'EGPG',
#  'NZRI',
#  'LHPA',
#  'KFZY',
#  'WI73',
#  '5MN7',
#  'MS55',
#  'EGCB',
#  '47GA',
#  'XA08',
#  'MS65',
#  '25NK',
#  'EVAH',
#  'TA28',
#  'KK36',
#  'TS08',
#  '05OI',
#  '6LL6',
#  'ETNH',
#  'KISB',
#  '8FL6',
#  '2IN2',
#  '8TS8',
#  '9OI8',
#  '20GA',
#  'NC59',
#  'CPR2',
#  '4II9',
#  '85LL',
#  'LFJS',
#  '0CO2',
#  'LBLS',
#  '51VA',
#  'MNBR',
#  'NH84',
#  'GA95',
#  'MD62',
#  '0NK1',
#  'VA25',
#  '03II',
#  'K8N8',
#  '15FL',
#  '84IL',
#  'K09J',
#  'UG24',
#  '3II9',
#  '7LA0',
#  '4VA0',
#  'K2A6',
#  'LFFI',
#  '2ID3',
#  'OR47',
#  'AR44',
#  '16PA',
#  'LHKH',
#  'VA13',
#  'SADM',
#  'CTK6',
#  'LFMX',
#  '9WI5',
#  'ESKX',
#  'TA49',
#  '53OK',
#  '54OK',
#  'MY47',
#  'K21D',
#  'AK46',
#  'MS11',
#  '4WI9',
#  '41OH',
#  'K3N6',
#  'LFLM',
#  'WI97',
#  '6OH4',
#  'SC58',
#  'EKMN',
#  '0KS9',
#  '4GE2',
#  '2MD3',
#  'KGAF',
#  'KXSA',
#  'CHL2',
#  'LYTR',
#  '97MT',
#  'EDPT',
#  'KCYO',
#  '83WA',
#  '86TE',
#  'XS21',
#  '79OH',
#  'MA89',
#  'MU69',
#  '1OA2',
#  'KC65',
#  '55MN',
#  'KS67',
#  'K3O9',
#  '67CO',
#  'KX58',
#  '65TA',
#  'EPLE',
#  'CFT2',
#  'K0M9',
#  'MD91',
#  'KTAN',
#  'RK52',
#  'KX07',
#  'SC01',
#  'KC75',
#  'AK18',
#  'KBIJ',
#  '44TS',
#  'K9A5',
#  'LFED',
#  'LIRM',
#  'K51J',
#  '0IN5',
#  'YBRS',
#  'EDTG',
#  '15PA',
#  '1LL2',
#  'AL60',
#  '24OH',
#  '34IL',
#  'ME96',
#  'SC15',
#  '4OH8',
#  'KS84',
#  'LDRO',
#  'CJT8',
#  '89OK',
#  '5TS0',
#  'K34R',
#  'CA03',
#  'SDZY',
#  'KLUD',
#  'ESMS',
#  'SN33',
#  'K7I4',
#  'K1F0',
#  'SIJR',
#  'KDKX',
#  '3AL6',
#  '69OK',
#  'CA88',
#  '07MN',
#  'EDKI',
#  'MI10',
#  'SBKP',
#  'AZ27',
#  'NE38',
#  'UKKH',
#  'IL86',
#  '66FD',
#  '9IS2',
#  'LFEX',
#  '4TA5',
#  'XS12',
#  'WI72',
#  '7XS0',
#  'KHDC',
#  '1WA9',
#  'NY60',
#  'II59',
#  '2II0',
#  'KD74',
#  '36AZ',
#  'LOLG',
#  'EGSO',
#  'NM20',
#  'WA41',
#  'CSE5',
#  'EDHF',
#  '53NY',
#  'KC62',
#  '8TE7',
#  '4PA0',
#  'ESVB',
#  'CMA2',
#  'EDCM',
#  'LGTL',
#  'CT32',
#  'LIAU',
#  '6NC2',
#  'KF14',
#  'K42U',
#  '0IA6',
#  'EPKR',
#  'SEAS',
#  'YCNQ',
#  'VA41',
#  'YYAK',
#  'IA68',
#  'OK79',
#  '00MN',
#  'LFDV',
#  'EGKH',
#  'EDGQ',
#  '10FA',
#  'KTME',
#  'LKUO',
#  'WSAC',
#  'TS85',
#  'LW75',
#  'ND99',
#  'KULS',
#  '0TX5',
#  'KK79',
#  'SIQE',
#  'DA14',
#  'K1R1',
#  '82FL',
#  'DE49',
#  'LS09',
#  'LFGG',
#  'MS62',
#  'K9G2',
#  'KW40',
#  '85TE',
#  'ESIA',
#  'WN26',
#  'MD00',
#  'K48K',
#  'GA20',
#  'VA87',
#  'KB16',
#  'KHQU',
#  'CSG5',
#  'SDCR',
#  'KDWU',
#  'SC34',
#  'K04A',
#  'NK07',
#  '33OI',
#  '55IS',
#  '55OI',
#  '22ID',
#  '6FL3',
#  'EDGW',
#  'VA65',
#  '41TN',
#  'LA79',
#  '7OH2',
#  'K41F',
#  '87TX',
#  '7MO7',
#  'MI58',
#  'SN22',
#  '29MO',
#  'EDBY',
#  'EDMK',
#  'ESME',
#  'FL74',
#  'SSXA',
#  '9IL6',
#  'NK83',
#  '47AZ',
#  '50OH',
#  'EDVJ',
#  'MS68',
#  'FL81',
#  '6OR7',
#  '4FL9',
#  'VT47',
#  'II96',
#  'SN13',
#  '6TS0',
#  'VE62',
#  'ID43',
#  'VT48',
#  '07TS',
#  'CAK3',
#  'YPPF',
#  'CRK2',
#  'PA08',
#  '7MI7',
#  '29CN',
#  'KF29',
#  'CNM2',
#  'KNUC',
#  'CSZ3',
#  'UWKG',
#  'YZCE',
#  '16KY',
#  '5TA2',
#  'KGDJ',
#  'MD14',
#  '87IS',
#  '07OR',
#  '40KY',
#  '18XA',
#  '57NC',
#  'OG00',
#  '47NY',
#  'FL19',
#  'CJZ2',
#  '2CN3',
#  'FL90',
#  'KVES',
#  '8OH3',
#  'LL34',
#  'ND52',
#  'CKH8',
#  'FD31',
#  'FL11',
#  '52NC',
#  '33CL',
#  'NK81',
#  'LEJU',
#  '84NC',
#  '4OR3',
#  '34LS',
#  '7WA7',
#  '3CL2',
#  '3AR7',
#  'CL04',
#  'PS23',
#  '97TN',
#  'CSB5',
#  'Z19M',
#  'CRF4',
#  '6TE1',
#  'SING',
#  'FL80',
#  '1CO4',
#  'EYPR',
#  'K0H1',
#  'IA16',
#  '35MI',
#  'ZBNY',
#  'KNOG',
#  '00IS',
#  'SNHJ',
#  '99XA',
#  'ESVQ',
#  'WA61',
#  'IL32',
#  'CLM2',
#  'K02C',
#  'SUAN',
#  '7TE3',
#  '16TX',
#  'SDZS',
#  'SC19',
#  '12MI',
#  '3WI2',
#  'YEES',
#  'IN47',
#  '53OH',
#  'IN20',
#  'KE45',
#  'LFXQ',
#  '48FL',
#  'TA50',
#  'NH88',
#  'WA37',
#  '12IN',
#  '14OI',
#  'LKRO',
#  '34IS',
#  'CFM8',
#  'KHUF',
#  'II45',
#  'WA67',
#  '16FA',
#  '9TX4',
#  'EDQF',
#  '3TX8',
#  'NV11',
#  'LFOJ',
#  'FL59',
#  'CSW6',
#  'CA07',
#  'EDRN',
#  'MHLP',
#  'SILI',
#  'K14A',
#  'TN85',
#  '6XS5',
#  '86IS',
#  'K9D4',
#  'OR74',
#  'MS54',
#  'EICN',
#  '85MN',
#  'LJCE',
#  '41PA',
#  '5MD8',
#  'AR82',
#  'EDRP',
#  'AR91',
#  'OH93',
#  '5IN3',
#  'KDLZ',
#  'EKHG',
#  'KT15',
#  '7KS4',
#  'YWOV',
#  '6MN8',
#  '3IL7',
#  'LEGC',
#  'CAH3',
#  '56NE',
#  '3LL1',
#  'KN13',
#  'EDRI',
#  'YKEP',
#  '1TN6',
#  '50AK',
#  'NC11',
#  'UMLI',
#  '4WA1',
#  'IN26',
#  '50FL',
#  '4LL0',
#  'SDST',
#  'KMMK',
#  'K55Y',
#  '52ND',
#  'VT62',
#  'KL31',
#  'KM45',
#  '61MU',
#  'K8G6',
#  'NR02',
#  'SBJR',
#  '5WI6',
#  '0WI9',
#  '29IN',
#  'NC39',
#  '3MS9',
#  'VG58',
#  'LFOL',
#  '78NC',
#  'WA04',
#  'KPUJ',
#  'PN91',
#  'LEOC',
#  '36CA',
#  'EFHL',
#  'SN16',
#  'EGLA',
#  'PN49',
#  'TN96',
#  'CAV9',
#  '8OK1',
#  'AR09',
#  '45TN',
#  'KPEO',
#  'KT85',
#  'K3GM',
#  'EVAD',
#  'KY94',
#  'K6K5',
#  '2VA3',
#  'VA67',
#  '0KY4',
#  'LFPT',
#  '4II6',
#  'CFH8',
#  'LA76',
#  'PA54',
#  'KI68',
#  '61OH',
#  'EHTE',
#  'KN71',
#  '12SC',
#  '0WN5',
#  'KSIF',
#  '0XA4',
#  'SN20',
#  '87IN',
#  'LFCO',
#  'TX40',
#  'YGDO',
#  'KDCM',
#  '2GA6',
#  '4SC7',
#  '1IS3',
#  '7GE5',
#  '06TX',
#  'NM88',
#  'NY73',
#  'NY94',
#  'K1D7',
#  'CEF3',
#  '2OK4',
#  'GMSL',
#  'ULLP',
#  'NY67',
#  'II39',
#  '9OI7',
#  '2KY8',
#  'K1M4',
#  'KRCZ',
#  '5PA2',
#  'TA00',
#  'SIDN',
#  'OH45',
#  'FD88',
#  '1NK8',
#  '19NK',
#  '9TN5',
#  'WI79',
#  '6CO1',
#  'EDCA',
#  '75NE',
#  'GE27',
#  'LGTP',
#  'WS78',
#  'SN08',
#  'NC47',
#  'OI62',
#  'LETF',
#  '9TX1',
#  '99CL',
#  '4IS5',
#  'LFYG',
#  'LDSR',
#  'K1H8',
#  'KM78',
#  'CYEE',
#  'CRM4',
#  '4KY8',
#  'NE17',
#  '7OI5',
#  'OI49',
#  'WA47',
#  '0LS6',
#  '67OK',
#  'EBBY',
#  'K2W5',
#  'VT31',
#  '2IN6',
#  'XS91',
#  'EDKB',
#  'TA03',
#  'CSZ4',
#  '5II2',
#  'PS82',
#  'AR88',
#  'KN37',
#  'K6L5',
#  'VG32',
#  'MDLL',
#  'SN18',
#  'RJST',
#  '70VA',
#  'YTLG',
#  '55IL',
#  'FL62',
#  '75TX',
#  '3WN9',
#  '7LL4',
#  'DE25',
#  '91GA',
#  'YBCH',
#  'CLB2',
#  'KAQO',
#  'CSP6',
#  'LFEJ',
#  'EGHY',
#  'K6J2',
#  'OR40',
#  'OG33',
#  '3AL8',
#  'FD35',
#  'TA81',
#  'LIRV',
#  'CNN3',
#  'TN47',
#  'CFX2',
#  'LS92',
#  'PR25',
#  'RKUC',
#  'ESSC',
#  '0IA3',
#  'WI20',
#  'VA27',
#  'XA78',
#  'K3A1',
#  'MS66',
#  '3AZ2',
#  'VG10',
#  'IN84',
#  '4NY1',
#  'TA21',
#  '0AK7',
#  'KO37',
#  'EGOW',
#  '62IS',
#  '9MS9',
#  'EBGG',
#  '4NC6',
#  'CFR5',
#  '44MU',
#  '61NJ',
#  '40XS',
#  'EDPU',
#  'IA24',
#  '53GA',
#  'LDPV',
#  'EDST',
#  'LTBW',
#  'IL31',
#  'CPF4',
#  'VA95',
#  '1AZ0',
#  '4NC0',
#  'MA44',
#  'K2R4',
#  'AZ57',
#  '00AK',
#  '0GE3',
#  'CGB3',
#  '0II0',
#  '11IN',
#  '69FL',
#  'K2IS',
#  'K5W4',
#  'LFGL',
#  '8OA7',
#  '9VA1',
#  'KA50',
#  'K8M9',
#  'PA74',
#  '4MO8',
#  'EDCU',
#  '0MS1',
#  'NM51',
#  'SDLY',
#  'K95F',
#  'SKGY',
#  'LE83',
#  'KOZW',
#  '9NY4',
#  'GE12',
#  'SC33',
#  '7MD0',
#  'KU42',
#  'WA08',
#  'NJ46',
#  '5FD3',
#  'RPLV',
#  'KE60',
#  '4VA8',
#  '4PN7',
#  '7II7',
#  'EDQH',
#  'SN36',
#  '8MD6',
#  'AZ63',
#  '5WN8',
#  'KRBM',
#  'MD48',
#  '13IN',
#  '8PA3',
#  '8IN7',
#  '94NC',
#  'KI76',
#  'XS77',
#  '99IA',
#  'LFPD',
#  '99SC',
#  '7CO3',
#  'MMPP',
#  '9SD8',
#  'EKHO',
#  'WBKU',
#  'EFRH',
#  '61KY',
#  'LSGT',
#  '6PA8',
#  'KOWX',
#  'NC77',
#  'VA89',
#  'OE50',
#  '13IA',
#  'KNFG',
#  '64IN',
#  'VT22',
#  '6OH6',
#  'MI55',
#  'IL64',
#  '3XS8',
#  'OH42',
#  'YPEF',
#  '0IN2',
#  'EPMX',
#  'SIRF',
#  'SSCV',
#  '77KY',
#  '52PA',
#  'KASD',
#  'LFSJ',
#  '6ID1',
#  '83FL',
#  'VA80',
#  '14LA',
#  'LYVR',
#  '6IL3',
#  '3SC2',
#  'KAWO',
#  'CEM4',
#  '3NC1',
#  'WI26',
#  '9VG9',
#  'KF36',
#  '30TX',
#  '1VA9',
#  '73OI',
#  'SSBZ',
#  'ESCF',
#  'LECJ',
#  'K4P3',
#  'IN55',
#  'WY01',
#  '1NY5',
#  '23NH',
#  'EGSQ',
#  'II15',
#  '8TS9',
#  '7NJ7',
#  'K4M2',
#  'KGKY',
#  '32LL',
#  'EPCD',
#  'ND76',
#  'KFIG',
#  '89OR',
#  'NC97',
#  'VA06',
#  '1AZ8',
#  'XS69',
#  'LSZN',
#  'KF69',
#  'KT82',
#  '7TA0',
#  'OH35',
#  '3SC4',
#  'EYLN',
#  'IA21',
#  '17II',
#  'II17',
#  'PN33',
#  '5NK0',
#  '7IS5',
#  'LOLW',
#  'LRCD',
#  '3OK0',
#  'OL23',
#  'LA30',
#  '2MT8',
#  'ID62',
#  'TN44',
#  'HEGS',
#  '07FA',
#  '44AK',
#  'NY84',
#  'EGKC',
#  'FD93',
#  '3MA2',
#  '52CL',
#  'OH44',
#  'KD14',
#  'LGRS',
#  '8IS2',
#  'PA88',
#  'UUBM',
#  'K8F3',
#  'KSSQ',
#  'IN05',
#  'LFGX',
#  '0CD2',
#  'LS68',
#  'LEMR',
#  'K2I3',
#  'NY09',
#  'LTBX',
#  'KC35',
#  'NV09',
#  'MO11',
#  'WI46',
#  '4MD8',
#  '19WA',
#  'KRPH',
#  '0MD6',
#  'CFY6',
#  'ENGS',
#  'KCDI',
#  '18OH',
#  '16TS',
#  'AL29',
#  'KK38',
#  'K82J',
#  'PN37',
#  '7NK4',
#  'EDRO',
#  '12XA',
#  'KVVS',
#  'ID13',
#  'KFTG',
#  '39FD',
#  '17GA',
#  '3TE1',
#  '7IL3',
#  '8IN9',
#  'LFLZ',
#  '21FA',
#  'KFKR',
#  'KD05',
#  'LFGI',
#  '21OI',
#  '2KS5',
#  'PN58',
#  'LE84',
#  '4NK3',
#  '1ND4',
#  '85GA',
#  'LBVR',
#  'NK74',
#  'LJNM',
#  '03OH',
#  'KL19',
#  'KETC',
#  'OMAS',
#  '77WI',
#  'RI20',
#  'KAAO',
#  'LL39',
#  'FL01',
#  'PA43',
#  '9NJ8',
#  '57XS',
#  'NZRW',
#  'WI51',
#  '9XS5',
#  '43NC',
#  'WV47',
#  '59NE',
#  '44VA',
#  'YRID',
#  'MY35',
#  '06FA',
#  '5FD5',
#  '7NY4',
#  'UT47',
#  'ME45',
#  'CA84',
#  'KFKS',
#  '93OH',
#  'KP19',
#  'LHSA',
#  '6OH7',
#  '0IA8',
#  'OH67',
#  'CRM5',
#  'LFFT',
#  'NC37',
#  'MY66',
#  'VA61',
#  'LKRY',
#  'VAJJ',
#  '63WA',
#  'CCI9',
#  '9NC9',
#  'SC43',
#  'YAVM',
#  '4SC4',
#  '24CT',
#  'KCHD',
#  '4TE6',
#  '3TX3',
#  '3MA5',
#  'TN73',
#  'CEQ3',
#  'K0F9',
#  'KU08',
#  'MA07',
#  'OI82',
#  'CYEG',
#  'KECU',
#  '2VA1',
#  'AR10',
#  'K4G5',
#  'CTH8',
#  'KPJC',
#  'VG28',
#  '73FD',
#  'LFAY',
#  'KORE',
#  'KSKI',
#  'KCKP',
#  'AL41',
#  'SEIS',
#  'MN85',
#  'LFFD',
#  'NY81',
#  'K7L8',
#  'KM41',
#  'FAHG',
#  'KM02',
#  '3WN8',
#  '3CO4',
#  'K2MO',
#  '35NY',
#  '1GE3',
#  'TA75',
#  'SDET',
#  '92MI',
#  'EPLN',
#  'ENEG',
#  'KJYO',
#  '97FL',
#  'SNPA',
#  'KI16',
#  '02OI',
#  'OJ40',
#  '7NK1',
#  'TS35',
#  'NE11',
#  'LGSD',
#  'CCN4',
#  'FAOI',
#  'CYPT',
#  'EDLH',
#  '0VA4',
#  'EDBJ',
#  '69CL',
#  'KBHC',
#  'RPLX',
#  'K2CB',
#  'K7F5',
#  'UD21',
#  'SN10',
#  'TA29',
#  'LKSK',
#  'UB18',
#  'LS49',
#  'HEOC',
#  'EDSE',
#  'K29M',
#  'CFX8',
#  '6NK8',
#  ...}

# %%
len(dest_not_in_icao)
# Out:
# 8320

# %%
data_pop = pd.read_csv("PassengerNumber.csv")
data_pop['typecode'] = data_pop['Typecode']
data_pop = data_pop.drop('Typecode', axis=1)
data_pop
# Out:
#     Passenger Capacity  Before Covid  During Covid  After Covid typecode
# 0                  266           239           172          239     A306
# 1                  312           280           202          280     A30B
# 2                  220           198           143          198     A310
# 3                  117           105            76          105     A318
# 4                  134           120            87          120    A319
# ..                 ...           ...           ...          ...      ...
# 90                  50            45            32           45     E145
# 91                  80            72            52           72     E170
# 92                  88            79            57           79     E175
# 93                 114           102            74          102     E190
# 94                 124           111            80          111     E195
#
# [95 rows x 5 columns]

# %%
filtered_com_major_final_withpop = pd.merge(filtered_com_major_final, data_pop, on='typecode', how='inner')

# %%
filtered_com_major_final_withpop.head()
# Out:
#   callsign typecode origin destination                  firstseen  \
# 0   CES219     A332   YSSY        EDDF  2018-12-31 01:05:29+00:00
# 1   CES219     A332   YSSY        EDDF  2019-01-22 01:01:45+00:00
# 2   CCA577     A332   YSSY        EDDF  2021-09-08 07:29:26+00:00
# 3  CES7219     A332   YSSY        EDDF  2021-11-16 02:10:15+00:00
# 4  CES7219     A332   YSSY        EDDF  2022-01-24 02:55:56+00:00
#
#                     lastseen                       day  Olatitude  Olongitude  \
# 0  2019-01-01 04:09:29+00:00 2019-01-01 00:00:00+00:00   -33.9461     151.177
# 1  2019-01-23 04:47:23+00:00 2019-01-23 00:00:00+00:00   -33.9461     151.177
# 2  2021-09-09 11:12:24+00:00 2021-09-09 00:00:00+00:00   -33.9461     151.177
# 3  2021-11-17 10:57:27+00:00 2021-11-17 00:00:00+00:00   -33.9461     151.177
# 4  2022-01-25 09:55:56+00:00 2022-01-25 00:00:00+00:00   -33.9461     151.177
#
#    Dlatitude  Dlongitude  Passenger Capacity  Before Covid  During Covid  \
# 0    50.0333     8.57056                 247           222           160
# 1    50.0333     8.57056                 247           222           160
# 2    50.0333     8.57056                 247           222           160
# 3    50.0333     8.57056                 247           222           160
# 4    50.0333     8.57056                 247           222           160
#
#    After Covid
# 0          222
# 1          222
# 2          222
# 3          222
# 4          222

# %%
filtered_com_major_final_withpop['pop'] = 0

# %%
filtered_com_major_final_withpop.head()
# Out:
#   callsign typecode origin destination                  firstseen  \
# 0   CES219     A332   YSSY        EDDF  2018-12-31 01:05:29+00:00
# 1   CES219     A332   YSSY        EDDF  2019-01-22 01:01:45+00:00
# 2   CCA577     A332   YSSY        EDDF  2021-09-08 07:29:26+00:00
# 3  CES7219     A332   YSSY        EDDF  2021-11-16 02:10:15+00:00
# 4  CES7219     A332   YSSY        EDDF  2022-01-24 02:55:56+00:00
#
#                     lastseen                       day  Olatitude  Olongitude  \
# 0  2019-01-01 04:09:29+00:00 2019-01-01 00:00:00+00:00   -33.9461     151.177
# 1  2019-01-23 04:47:23+00:00 2019-01-23 00:00:00+00:00   -33.9461     151.177
# 2  2021-09-09 11:12:24+00:00 2021-09-09 00:00:00+00:00   -33.9461     151.177
# 3  2021-11-17 10:57:27+00:00 2021-11-17 00:00:00+00:00   -33.9461     151.177
# 4  2022-01-25 09:55:56+00:00 2022-01-25 00:00:00+00:00   -33.9461     151.177
#
#    Dlatitude  Dlongitude  Passenger Capacity  Before Covid  During Covid  \
# 0    50.0333     8.57056                 247           222           160
# 1    50.0333     8.57056                 247           222           160
# 2    50.0333     8.57056                 247           222           160
# 3    50.0333     8.57056                 247           222           160
# 4    50.0333     8.57056                 247           222           160
#
#    After Covid  pop
# 0          222    0
# 1          222    0
# 2          222    0
# 3          222    0
# 4          222    0

# %%
count_after_withpop = filtered_com_major_final_withpop.groupby('day').count()
count_after_withpop
# Out:
#                            callsign  typecode  origin  destination  firstseen  \
# day
# 2019-01-01 00:00:00+00:00     12986     12986   12986        12986      12986
# 2019-01-02 00:00:00+00:00     15192     15192   15192        15192      15192
# 2019-01-03 00:00:00+00:00     15890     15890   15890        15890      15890
# 2019-01-04 00:00:00+00:00     16110     16110   16110        16110      16110
# 2019-01-05 00:00:00+00:00     14152     14152   14152        14152      14152
# ...                             ...       ...     ...          ...        ...
# 2022-12-27 00:00:00+00:00     12545     12545   12545        12545      12545
# 2022-12-28 00:00:00+00:00     16379     16379   16379        16379      16379
# 2022-12-29 00:00:00+00:00     17043     17043   17043        17043      17043
# 2022-12-30 00:00:00+00:00     17694     17694   17694        17694      17694
# 2022-12-31 00:00:00+00:00     15744     15744   15744        15744      15744
#
#                            lastseen  Olatitude  Olongitude  Dlatitude  \
# day
# 2019-01-01 00:00:00+00:00     12986      12986       12986      12986
# 2019-01-02 00:00:00+00:00     15192      15192       15192      15192
# 2019-01-03 00:00:00+00:00     15890      15890       15890      15890
# 2019-01-04 00:00:00+00:00     16110      16110       16110      16110
# 2019-01-05 00:00:00+00:00     14152      14152       14152      14152
# ...                             ...        ...         ...        ...
# 2022-12-27 00:00:00+00:00     12545      12545       12545      12545
# 2022-12-28 00:00:00+00:00     16379      16379       16379      16379
# 2022-12-29 00:00:00+00:00     17043      17043       17043      17043
# 2022-12-30 00:00:00+00:00     17694      17694       17694      17694
# 2022-12-31 00:00:00+00:00     15744      15744       15744      15744
#
#                            Dlongitude  Passenger Capacity  Before Covid  \
# day
# 2019-01-01 00:00:00+00:00       12986               12986         12986
# 2019-01-02 00:00:00+00:00       15192               15192         15192
# 2019-01-03 00:00:00+00:00       15890               15890         15890
# 2019-01-04 00:00:00+00:00       16110               16110         16110
# 2019-01-05 00:00:00+00:00       14152               14152         14152
# ...                               ...                 ...           ...
# 2022-12-27 00:00:00+00:00       12545               12545         12545
# 2022-12-28 00:00:00+00:00       16379               16379         16379
# 2022-12-29 00:00:00+00:00       17043               17043         17043
# 2022-12-30 00:00:00+00:00       17694               17694         17694
# 2022-12-31 00:00:00+00:00       15744               15744         15744
#
#                            During Covid  After Covid    pop
# day
# 2019-01-01 00:00:00+00:00         12986        12986  12986
# 2019-01-02 00:00:00+00:00         15192        15192  15192
# 2019-01-03 00:00:00+00:00         15890        15890  15890
# 2019-01-04 00:00:00+00:00         16110        16110  16110
# 2019-01-05 00:00:00+00:00         14152        14152  14152
# ...                                 ...          ...    ...
# 2022-12-27 00:00:00+00:00         12545        12545  12545
# 2022-12-28 00:00:00+00:00         16379        16379  16379
# 2022-12-29 00:00:00+00:00         17043        17043  17043
# 2022-12-30 00:00:00+00:00         17694        17694  17694
# 2022-12-31 00:00:00+00:00         15744        15744  15744
#
# [1458 rows x 15 columns]

# %%
plt.figure(figsize=(20, 10))
plt.plot(count_before['callsign'])
plt.plot(count_after['callsign'])
plt.plot(count_after_withpop['callsign'])
plt.show()

# %%
filtered_com_major_final_withpop.dtypes
# Out:
# callsign                           object
# typecode                           object
# origin                             object
# destination                        object
# firstseen                          object
# lastseen                           object
# day                   datetime64[ns, UTC]
# Olatitude                         float64
# Olongitude                        float64
# Dlatitude                         float64
# Dlongitude                        float64
# Passenger Capacity                  int64
# Before Covid                        int64
# During Covid                        int64
# After Covid                         int64
# pop                                 int64
# dtype: object

# %%
cutoff_date_before = pd.to_datetime('2020-01-01')
cutoff_date_before
# Out:
# Timestamp('2020-01-01 00:00:00')

# %%
cutoff_date_before = pd.to_datetime('2020-01-01', utc = True)
filtered_com_major_final_withpop_before = filtered_com_major_final_withpop[filtered_com_major_final_withpop['day'] < cutoff_date_before]
filtered_com_major_final_withpop_before_ts = filtered_com_major_final_withpop_before.groupby('day')['Before Covid'].sum()
filtered_com_major_final_withpop_before_ts
# Out:
# day
# 2019-01-01 00:00:00+00:00    2345857
# 2019-01-02 00:00:00+00:00    2699299
# 2019-01-03 00:00:00+00:00    2847235
# 2019-01-04 00:00:00+00:00    2888981
# 2019-01-05 00:00:00+00:00    2561017
#                               ...
# 2019-12-27 00:00:00+00:00    3815215
# 2019-12-28 00:00:00+00:00    2945116
# 2019-12-29 00:00:00+00:00    3621849
# 2019-12-30 00:00:00+00:00    3600757
# 2019-12-31 00:00:00+00:00    3481904
# Name: Before Covid, Length: 365, dtype: int64

# %%
cutoff_date_start = pd.to_datetime('2020-03-25', utc = True)
cutoff_date_during = pd.to_datetime('2022-01-01', utc = True)
filtered_com_major_final_withpop_during = filtered_com_major_final_withpop[(filtered_com_major_final_withpop['day'] > cutoff_date_start) & (filtered_com_major_final_withpop['day'] < cutoff_date_during)]
filtered_com_major_final_withpop_during_ts = filtered_com_major_final_withpop_during.groupby('day')['During Covid'].sum()
filtered_com_major_final_withpop_during_ts
# Out:
# day
# 2020-03-26 00:00:00+00:00    1083752
# 2020-03-27 00:00:00+00:00     955865
# 2020-03-28 00:00:00+00:00     836226
# 2020-03-29 00:00:00+00:00     805522
# 2020-03-30 00:00:00+00:00     787440
#                               ...
# 2021-12-27 00:00:00+00:00    1825908
# 2021-12-28 00:00:00+00:00    1840596
# 2021-12-29 00:00:00+00:00    1898239
# 2021-12-30 00:00:00+00:00    1951169
# 2021-12-31 00:00:00+00:00    1808788
# Name: During Covid, Length: 643, dtype: int64

# %%
filtered_com_major_final_withpop_after = filtered_com_major_final_withpop[filtered_com_major_final_withpop['day'] >= cutoff_date_during]
filtered_com_major_final_withpop_after_ts = filtered_com_major_final_withpop_after.groupby('day')['After Covid'].sum()
filtered_com_major_final_withpop_after_ts
# Out:
# day
# 2022-01-01 00:00:00+00:00    2029891
# 2022-01-02 00:00:00+00:00    2395303
# 2022-01-03 00:00:00+00:00    2553924
# 2022-01-04 00:00:00+00:00    2633319
# 2022-01-05 00:00:00+00:00    2573020
#                               ...
# 2022-12-27 00:00:00+00:00    2002244
# 2022-12-28 00:00:00+00:00    2743934
# 2022-12-29 00:00:00+00:00    2869106
# 2022-12-30 00:00:00+00:00    2960106
# 2022-12-31 00:00:00+00:00    2665107
# Name: After Covid, Length: 365, dtype: int64

# %%
plt.figure(figsize=(20, 10))
plt.plot(filtered_com_major_final_withpop_before_ts)
plt.plot(filtered_com_major_final_withpop_during_ts)
plt.plot(filtered_com_major_final_withpop_after_ts)
plt.show()

# %%
before=pd.DataFrame(filtered_com_major_final_withpop_before_ts)
before
# Out:
#                            Before Covid
# day
# 2019-01-01 00:00:00+00:00       2345857
# 2019-01-02 00:00:00+00:00       2699299
# 2019-01-03 00:00:00+00:00       2847235
# 2019-01-04 00:00:00+00:00       2888981
# 2019-01-05 00:00:00+00:00       2561017
# ...                                 ...
# 2019-12-27 00:00:00+00:00       3815215
# 2019-12-28 00:00:00+00:00       2945116
# 2019-12-29 00:00:00+00:00       3621849
# 2019-12-30 00:00:00+00:00       3600757
# 2019-12-31 00:00:00+00:00       3481904
#
# [365 rows x 1 columns]

# %%
during=pd.DataFrame(filtered_com_major_final_withpop_during_ts)
during
# Out:
#                            During Covid
# day
# 2020-03-26 00:00:00+00:00       1083752
# 2020-03-27 00:00:00+00:00        955865
# 2020-03-28 00:00:00+00:00        836226
# 2020-03-29 00:00:00+00:00        805522
# 2020-03-30 00:00:00+00:00        787440
# ...                                 ...
# 2021-12-27 00:00:00+00:00       1825908
# 2021-12-28 00:00:00+00:00       1840596
# 2021-12-29 00:00:00+00:00       1898239
# 2021-12-30 00:00:00+00:00       1951169
# 2021-12-31 00:00:00+00:00       1808788
#
# [643 rows x 1 columns]

# %%
after=pd.DataFrame(filtered_com_major_final_withpop_after_ts)
after
# Out:
#                            After Covid
# day
# 2022-01-01 00:00:00+00:00      2029891
# 2022-01-02 00:00:00+00:00      2395303
# 2022-01-03 00:00:00+00:00      2553924
# 2022-01-04 00:00:00+00:00      2633319
# 2022-01-05 00:00:00+00:00      2573020
# ...                                ...
# 2022-12-27 00:00:00+00:00      2002244
# 2022-12-28 00:00:00+00:00      2743934
# 2022-12-29 00:00:00+00:00      2869106
# 2022-12-30 00:00:00+00:00      2960106
# 2022-12-31 00:00:00+00:00      2665107
#
# [365 rows x 1 columns]

# %%
plt.plot(before.rolling(window = 7).mean());

# %%
plt.plot(before.rolling(window = 30).mean());

# %%
plt.figure(figsize = (20,10))
plt.plot(before.index,before['Before Covid'], label = 'count', color = 'red')
plt.plot(before.index,before['Before Covid'].rolling(window = 7).mean(), label = 'count', color = 'blue');

# %%
xTime = before.index

yGreen = before['Before Covid']

plt.figure(figsize = (20,10))
plt.subplot(311)
plt.title('before')
plt.xlabel('time')
plt.ylabel('count')
beforedata = plt.plot(xTime,yGreen, label = 'Green', color = 'green')
beforetime = plt.plot(xTime,yGreen.rolling(window = 7).mean(), label='Green Mean', linestyle='--',color='blue')

xTime = during.index
yGreen = during['During Covid']
plt.figure(figsize = (20,10))
plt.subplot(312)
plt.title('during')
plt.xlabel('time')
plt.ylabel('count')
yellow_data_line = plt.plot(xTime,yGreen, label = 'Yellow', color = 'yellow')
yellow_mean_line = plt.plot(xTime,yGreen.rolling(window = 7).mean(), label='Yellow Mean', linestyle='--',color='blue')


xTime = after.index
yGreen = after['After Covid']
plt.figure(figsize = (20,10))
plt.subplot(313)
plt.title('After')
plt.xlabel('time')
plt.ylabel('count')
yellow_data_line = plt.plot(xTime,yGreen, label = 'Red', color = 'red')
yellow_mean_line = plt.plot(xTime,yGreen.rolling(window = 7).mean(), label='Yellow Mean', linestyle='--',color='blue')
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.plot(filtered_com_major_final_withpop_before_ts)
plt.plot(filtered_com_major_final_withpop_during_ts)
plt.plot(filtered_com_major_final_withpop_after_ts)
plt.plot(before.index,before['Before Covid'].rolling(window = 7).mean(), label='Green Mean', linestyle='--',color='red')
plt.plot(during.index,during['During Covid'].rolling(window = 7).mean(), label='Green Mean', linestyle='--',color='red')
plt.plot(after.index,after['After Covid'].rolling(window = 7).mean(), label='Green Mean', linestyle='--',color='red')
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.plot(filtered_com_major_final_withpop_before_ts)
plt.plot(filtered_com_major_final_withpop_during_ts)
plt.plot(filtered_com_major_final_withpop_after_ts)
plt.plot(before.index,before['Before Covid'].rolling(window = 30).mean(), label='Green Mean', linestyle='--',color='red')
plt.plot(during.index,during['During Covid'].rolling(window = 30).mean(), label='Green Mean', linestyle='--',color='red')
plt.plot(after.index,after['After Covid'].rolling(window = 30).mean(), label='Green Mean', linestyle='--',color='red')
plt.show()

# %%
before.dtypes
# Out:
# Before Covid    int64
# dtype: object

# %%
plot_acf(before['Before Covid'], lags = 7)

# %%
plot_acf(before['Before Covid'], lags = 30)

# %%
before.reset_index(inplace=True)
during.reset_index(inplace=True)
after.reset_index(inplace=True)
before
# Out:
#                           day  Before Covid
# 0   2019-01-01 00:00:00+00:00       2345857
# 1   2019-01-02 00:00:00+00:00       2699299
# 2   2019-01-03 00:00:00+00:00       2847235
# 3   2019-01-04 00:00:00+00:00       2888981
# 4   2019-01-05 00:00:00+00:00       2561017
# ..                        ...           ...
# 360 2019-12-27 00:00:00+00:00       3815215
# 361 2019-12-28 00:00:00+00:00       2945116
# 362 2019-12-29 00:00:00+00:00       3621849
# 363 2019-12-30 00:00:00+00:00       3600757
# 364 2019-12-31 00:00:00+00:00       3481904
#
# [365 rows x 2 columns]

# %%
lm=sm.OLS(before['Before Covid'],sm.add_constant(before.index)).fit()
print (lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Before Covid   R-squared:                       0.657
# Model:                            OLS   Adj. R-squared:                  0.656
# Method:                 Least Squares   F-statistic:                     695.6
# Date:                Fri, 26 Apr 2024   Prob (F-statistic):           2.23e-86
# Time:                        16:28:21   Log-Likelihood:                -5064.6
# No. Observations:                 365   AIC:                         1.013e+04
# Df Residuals:                     363   BIC:                         1.014e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         2.6e+06   2.69e+04     96.571      0.000    2.55e+06    2.65e+06
# x1          3376.1497    128.012     26.374      0.000    3124.412    3627.887
# ==============================================================================
# Omnibus:                       13.659   Durbin-Watson:                   0.868
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.132
# Skew:                          -0.467   Prob(JB):                     0.000854
# Kurtosis:                       3.236   Cond. No.                         420.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
lm=sm.OLS(during['During Covid'],sm.add_constant(during.index)).fit()
print (lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           During Covid   R-squared:                       0.705
# Model:                            OLS   Adj. R-squared:                  0.704
# Method:                 Least Squares   F-statistic:                     1530.
# Date:                Fri, 26 Apr 2024   Prob (F-statistic):          6.06e-172
# Time:                        16:28:21   Log-Likelihood:                -8831.2
# No. Observations:                 643   AIC:                         1.767e+04
# Df Residuals:                     641   BIC:                         1.768e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.065e+05   1.76e+04     45.808      0.000    7.72e+05    8.41e+05
# x1          1857.0781     47.480     39.113      0.000    1763.844    1950.312
# ==============================================================================
# Omnibus:                        9.675   Durbin-Watson:                   0.300
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               14.769
# Skew:                           0.078   Prob(JB):                     0.000621
# Kurtosis:                       3.726   Cond. No.                         741.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
lm=sm.OLS(after['After Covid'],sm.add_constant(after.index)).fit()
print (lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            After Covid   R-squared:                       0.213
# Model:                            OLS   Adj. R-squared:                  0.211
# Method:                 Least Squares   F-statistic:                     98.12
# Date:                Fri, 26 Apr 2024   Prob (F-statistic):           1.24e-20
# Time:                        16:28:21   Log-Likelihood:                -5108.1
# No. Observations:                 365   AIC:                         1.022e+04
# Df Residuals:                     363   BIC:                         1.023e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.631e+06   3.03e+04     86.739      0.000    2.57e+06    2.69e+06
# x1          1428.5075    144.209      9.906      0.000    1144.917    1712.098
# ==============================================================================
# Omnibus:                      137.361   Durbin-Watson:                   0.766
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              594.582
# Skew:                          -1.586   Prob(JB):                    7.73e-130
# Kurtosis:                       8.388   Cond. No.                         420.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
matplotlib.rcParams['figure.figsize'] = [12, 8]
res = sm.tsa.seasonal_decompose(before['Before Covid'],model='additive',period=7)
res.plot()
plt.show()

# %%
matplotlib.rcParams['figure.figsize'] = [12, 8]
res = sm.tsa.seasonal_decompose(before['Before Covid'],model='additive',period=30)
res.plot()
plt.show()

# %%
matplotlib.rcParams['figure.figsize'] = [12, 8]
res = sm.tsa.seasonal_decompose(during['During Covid'],model='additive',period=7)
res.plot()
plt.show()

# %%
matplotlib.rcParams['figure.figsize'] = [12, 8]
res = sm.tsa.seasonal_decompose(after['After Covid'],model='additive',period=7)
res.plot()
plt.show()

# %%
plot_acf(after['After Covid'], lags = 30)

# %%
plot_acf(after['After Covid'], lags = 7)
